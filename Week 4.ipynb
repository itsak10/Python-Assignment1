# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __ADITYA KOSHTI__
#
# I am currently studying Bsc. in Data Science.

# %% [markdown]
# _I am interested in data science because i like to find the hidden patterns_

# %% [markdown]
# ### The code in the 5 cell is going to perform subtraction .

# %%
print(99-33)
# Out:
# 66

# %% [markdown]
# #Bulleted list
#  - 1
#     - 2
#
# #Numbered list
#
# 1. A
# 1. N
#
# #Table
#
# | Test | Positive/Negative | Accuracy |
# | ---- | ----------------- | -------- |
# | Corona | Positive | 90% |
# | HIV | Negative | 97% |
